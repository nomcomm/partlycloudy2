# %% [markdown]
# ## Extract functional MRI data
#
# The goal is to extract the fmri data (that were recorded during movie viewing) via a masker and save them to disk.
#
# Note: Due to the large size of the dataset, this is done from a harddisk (after downloading the data from openNeuro). Thus, this step is documented, but cannot be exectuted unless you download and preprocess the data exactly as indicated.

# %% [markdown]
# #### import modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sys, os, nilearn, shutil, glob
from nilearn import input_data, datasets
from nilearn import datasets, plotting
from nilearn.image import new_img_like, load_img, get_data
from nilearn.interfaces.fmriprep import load_confounds
from nilearn import input_data, datasets

# %% [markdown]
# #### set up the brain masker

# %%
from nilearn.maskers import NiftiMasker

#mask_path = '/Volumes/Backup Plus/twins_fmriprep/sub-0001/ses-02/anat/sub-0001_ses-02_space-MNI152NLin2009cAsym_desc-brain_mask.nii.gz'

brain_masker = NiftiMasker( #mask_img = mask_path,
                            detrend     = True, 
                            standardize = True,
                            high_pass   = 0.01, 
                            t_r         = 0.8, 
                            low_pass    = 0.12,
                            mask_strategy = 'whole-brain-template',
                          );


brain_masker.fit('/Volumes/Backup Plus/twins_fmriprep/sub-0001/ses-02/func/sub-0001_ses-02_task-partlycloudy_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz')
# Out:
# NiftiMasker(detrend=True, high_pass=0.01, low_pass=0.12,
#             mask_strategy='whole-brain-template', standardize=True, t_r=0.8)

# %%
report = brain_masker.generate_report()

# %%
report
# Out:
# <!-- CSS for the report -->
# <link rel="stylesheet" href="https://unpkg.com/purecss@1.0.0/build/pure-min.css" integrity="sha384-nn4HPE8lTHyVtfCBi5yW9d20FjT8BJwUXyWZT9InLYax14RDjBj46LmSztkmNP9w" crossorigin="anonymous">
# <link rel="stylesheet" href="https://unpkg.com/purecss@1.0.0/build/grids-responsive-min.css">
# <style type="text/css">
#
# /* Add a gutter to Pure's Columns */
# .pure-g > div {
#   -webkit-box-sizing: border-box;
#   -moz-box-sizing: border-box;
#   box-sizing: border-box;
# }
#
# .pure-g > div {
#   padding: 0 0.5em;
# }
#
# /*!
# Pure-button class copied from pure-min.css,
# in case reports are displayed offline.
#
# Pure v1.0.0
# Copyright 2013 Yahoo!
# Licensed under the BSD License.
# https://github.com/yahoo/pure/blob/master/LICENSE.md
# */
#
# .pure-button {
#     /* Structure */
#     display: inline-block;
#     zoom: 1;
#     line-height: normal;
#     white-space: nowrap;
#     vertical-align: middle;
#     text-align: center;
#     cursor: pointer;
#     -webkit-user-drag: none;
#     -webkit-user-select: none;
#        -moz-user-select: none;
#         -ms-user-select: none;
#             user-select: none;
#     box-sizing: border-box;
# }
#
# .pure-button {
#     /* Button styling */
#     font-family: inherit;
#     font-size: 100%;
#     padding: 0.5em 1em;
#     color: #444; /* rgba not supported (IE 8) */
#     color: rgba(0, 0, 0, 0.80); /* rgba supported */
#     border: 1px solid #999;  /*IE 6/7/8*/
#     border: none rgba(0, 0, 0, 0);  /*IE9 + everything else*/
#     background-color: #E6E6E6;
#     text-decoration: none;
#     border-radius: 2px;
# }
#
# /*!
# End pure-button class definition from pure-min.css
# */
#
# div.nilearn_report {
#     padding-top: 0px;
#     border: solid rgb(150, 150, 150);
#     border-width: 1pt;
#     border-radius: 6pt;
#     overflow: hidden;  /* Needed to avoid scrolling in jupyter :( */
#     color: black;
#     background-color: white;
# }
#
# .terminal div.nilearn_report {
#     max-width: min(50ex, 100vw); /* Needed in vscode */
# }
#
# /* Isolate us a bit from the styles specified by other stylesheets */
#
# div.nilearn_report h1 {
#     text-align: left;
#     margin-left: 0pt;
#     margin-right: 0pt;
#     padding-top: 5pt;
#     font-size: 1.8em;
#     padding-left: 5pt;
# }
#
# div.nilearn_report h1:first-child {
#     margin-top: 0pt;
#     background-color: #f5f5f5;
#     border-radius: 6pt 6pt 0pt 0pt;
#     padding-left: 5pt;
# }
#
# div.nilearn_report summary::-webkit-details-marker {
#     margin-right: 2px;
# }
#
# div.nilearn_report summary:focus {
#     outline-style: none;
# }
#
# div.nilearn_report table {
#     max-width: 100%;
#     border-collapse: collapse;
#     margin:50px auto;
#     float: right;
# }
#
# div.nilearn_report thead th {
#   text-align: center;
# }
#
# div.nilearn_report tbody tr:nth-child(even) {
#    background-color: #ddd;
# }
#
# div.nilearn_report details {
#     overflow-x: visible;
# }
#
# div.nilearn_report div.raise {
#     z-index: 1;
#
# }
#
# /* Tooltip container */
# div.nilearn_report .withtooltip {
#   position: relative;
#   border-bottom: 1px dotted black; /* If you want dots under the hoverable text */
# }
#
# /* Tooltip text */
# div.nilearn_report .withtooltip .tooltiptext {
#   visibility: hidden;
#   max-width: 35em;
#   width: 90%;
#   background-color: rgba(24,24,24,0.9);
#   color: #fff;
#   text-align: left;
#   font-size: 12pt;
#   font-weight: 200;
#   border-radius: 6px;
#   padding: 5px;css=resource_path.joinpath('css'),
#
#   margin-left: 3pt;
#
#   /* Position the tooltip text - see examples below! */
#   position: absolute;
#   z-index: 2;
#
#   width: 99%;
#   left: 2pt;
#   top: 133%;
# }
#
# /* Show the tooltip text when you mouse over the tooltip container */
# div.nilearn_report .withtooltip:hover .tooltiptext {
#   visibility: visible;
# }
#
# div.nilearn_report .image {
#   position: relative;
#   height: auto;
#   width: 100%;
# }
#
# div.nilearn_report .image .overlay {
#   position: absolute;
#   top: 0;
#   left: 0;
#   opacity: 0;
#   transition: .5s ease;
#   height: auto;
#   width: 100%;
#   -webkit-transition: .5s ease;
# }
#
# div.nilearn_report .image:hover .overlay {
#   opacity: 1;
# }
#
# .elem-warn {
#     color: #FF0000;
#     font-weight: bold;
# }
#
# </style>
# <div class="nilearn_report">
#   <h1 class="withtooltip">
#     NiftiMasker
#     <span class="tooltiptext">Applying a mask to extract time-series from Niimg-like objects.
#
#     NiftiMasker is useful when preprocessing (detrending, standardization,
#     resampling, etc.) of in-mask :term:`voxels&lt;voxel&gt;` is necessary.
#     Use case: working with time series of resting-state or task maps.
#
#     </span>
#   </h1>
#   <div class="pure-g">
#   <div class="pure-u-1 pure-u-md-2-3">
#       <div class="image">
#       <img class="pure-img" width="100%" src="data:image/svg+xml;base64,..." alt="image"/>
#       </div>
#   </div>
#   <div class="pure-u-1 pure-u-md-1-3 raise">
#       <p class="elem-desc">This report shows the input Nifti image overlaid with the outlines of the mask (in green). We recommend to inspect the report for the overlap between the mask and its input image. </p>
#     <p></p>
#     <details>
#       <summary class="pure-button">Parameters</summary>
#       <table class="pure-table">
#         <thead>
#           <tr>
#             <th>Parameter</th>
#             <th>Value</th>
#           </tr>
#         </thead>
#
#         <tbody>
#             <tr>
#               <td data-column="Parameter">detrend</td>
#               <td data-column="Value">True</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">dtype</td>
#               <td data-column="Value">None</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">high_pass</td>
#               <td data-column="Value">0.01</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">high_variance_confounds</td>
#               <td data-column="Value">False</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">low_pass</td>
#               <td data-column="Value">0.12</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">mask_args</td>
#               <td data-column="Value">None</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">mask_img</td>
#               <td data-column="Value">None</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">mask_strategy</td>
#               <td data-column="Value">whole-brain-template</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">memory</td>
#               <td data-column="Value">Memory(location=None)</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">memory_level</td>
#               <td data-column="Value">1</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">reports</td>
#               <td data-column="Value">True</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">runs</td>
#               <td data-column="Value">None</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">smoothing_fwhm</td>
#               <td data-column="Value">None</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">standardize</td>
#               <td data-column="Value">True</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">standardize_confounds</td>
#               <td data-column="Value">True</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">t_r</td>
#               <td data-column="Value">0.8</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">target_affine</td>
#               <td data-column="Value">None</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">target_shape</td>
#               <td data-column="Value">None</td>
#             </tr>
#             <tr>
#               <td data-column="Parameter">verbose</td>
#               <td data-column="Value">0</td>
#             </tr>
#         </tbody>
#       </table>
#
#     </details>
#     </div>
#   </div>
# </div>

# %% [markdown]
# #### set up files

# %%
mylist = [f for f in glob.glob("/Volumes/Backup Plus/twins_fmriprep/sub*/ses-02/func/*_ses-02_task-partlycloudy_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz")]
print(len(mylist)) #[-84:65]
mylist[:3]
# Out:
# 289
# ['/Volumes/Backup Plus/twins_fmriprep/sub-0001/ses-02/func/sub-0001_ses-02_task-partlycloudy_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/Volumes/Backup Plus/twins_fmriprep/sub-0422/ses-02/func/sub-0422_ses-02_task-partlycloudy_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/Volumes/Backup Plus/twins_fmriprep/sub-0004/ses-02/func/sub-0004_ses-02_task-partlycloudy_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz']

# %%
path_dir          = "/Volumes/Backup Plus/twins_partly_cloudy_extracted/"

# %%
for curr_file in mylist:

    confounds_simple, sample_mask = load_confounds(
                                     curr_file,    
                                     strategy=["motion", "wm_csf"],
                                     motion="basic", 
                                     wm_csf="basic")

    curr_out_file = curr_file[-84:65]
    curr_out_file_path = path_dir + curr_out_file + '_LTR_Z_THP001_LP012_voxelwise.npy'
    print(curr_out_file_path)

    if not os.path.exists(curr_out_file_path):
            time_series = brain_masker.fit_transform(curr_file,confounds=confounds_simple)
            print(time_series.shape)
        
            np.save(curr_out_file_path, time_series)
# Out:
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0001_LTR_Z_THP001_LP012_voxelwise.npy
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0422_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0004_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0139_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0421_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0141_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0005_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0420_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0006_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0144_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0419_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0148_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0007_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0418_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0150_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0010_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0417_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0013_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0151_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0415_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0152_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0413_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0015_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0154_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0412_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0016_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0155_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0411_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0017_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0156_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0410_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0018_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0157_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0409_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0019_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0158_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0408_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0020_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0159_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0404_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0021_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0160_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0403_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0022_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0161_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0402_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0024_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0162_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0401_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0025_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0163_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0400_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0028_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0164_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0397_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0029_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0165_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0396_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0030_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0166_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0395_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0031_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0167_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0394_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0032_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0168_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0392_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0034_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0170_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0390_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0035_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0171_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0389_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0036_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0173_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0388_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0037_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0174_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0387_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0038_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0175_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0385_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0041_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0178_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0384_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0042_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0181_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0382_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0043_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0182_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0381_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0044_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0183_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0380_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0045_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0184_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0378_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0047_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0185_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0377_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0048_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0186_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0376_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0049_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0187_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0375_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0050_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0188_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0374_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0051_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0189_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0372_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0053_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0190_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0371_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0054_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0193_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0369_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0055_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0194_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0368_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0057_LTR_Z_THP001_LP012_voxelwise.npy
# (380, 124045)
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0195_LTR_Z_THP001_LP012_voxelwise.npy
# /Volumes/Backup Plus/twins_partly_cloudy_extracted/sub-0366_LTR_Z_THP001_LP012_voxelwise.npy

# %%
124045/(81*96*81)
# Out:
# 0.1969418406746939

# %%
os.listdir(path_dir)
